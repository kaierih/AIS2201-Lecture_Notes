# %%
from numpy import sin, cos, pi, exp
import numpy as np
import scipy.signal as sig
import matplotlib.pyplot as plt
from IPython.display import Audio

# Configure default pyplot settings
plt.rcParams["figure.figsize"] = [8.00, 4.5]
plt.rcParams["figure.autolayout"] = True
plt.rcParams["axes.grid"] = True
plt.rcParams["axes.xmargin"] = 0.0

# Enable importing from modules in top-level directory
from sys import path
if path[0] != '..': path.insert(0, '..')

# %% [markdown]
# <img src="figures/NTNU_logo_vertical.svg" align="left" width="30%">
# <br clear="all" />
#
# # Introduction
#
# * **Course AIS2201 - Signal Processing**
# * **Week 34**
# * **Lecturer: Kai Erik Hoff**

# %% [markdown]
# # Topics
#
# * What is Digital Signal Processing
# * Advice on approaching the subject material
# * Practical information about the course
# * Digital signal processing using Python

# %% [markdown]
# # Why learn about digital signal processing?

# %% [markdown]
# * What expectations do you have in terms of learning outcomes?

# %% [markdown]
# ##### Notes:
# Digital signal processing is a broad field of study with a surprisingly wide range of applications, ranging from wireless communication systems to mapping of structural dynamics and even analysis of stock exchange data. As aspiring automation engineers, there are two main areas in which digital signal processing are likely to be of use:
#
# 1. **Signal analysis in troubleshooting.**<br>
# Making use of tools such as spectral representation of a signal can help identify sources of disturbance and/or failure in an automated system relying on sensor measurements.
# 2. **Extracting desired information from imprecise/indirect measurements.**<br>
# Digital filters and fourier transforms are commonly used to aid in estimating properties which are present in have to be calculated by analyzing a measured signal.
#
# In fact, it is highly likely that you have already made use of some basic signal processing tools earlier in your studies. A common first encounter with digital signal processing for instance is writing a program to calculate a moving average of sensor values to reduce measurement noise. Furthermore, if you have taken the course AIS2102 - Dynamical Systems, you would have spent three weeks learing about [discretization](https://en.wikipedia.org/wiki/Discretization), which covers the use of digital filters to emulate a dynamical system in discrete time.
#
# This course aims to provide the necessary understanding to make use of fundamental signal processing tools which are among the most universally used. The teaching activities take a problem-oriented approach to introducing central concepts, and covers the systems theory necessary to design and analyze a digital signal processing system, as well as implementation of digital signal processing systems on a microprocessor.

# %% [markdown]
# # What *is* signal processing?

# %% [markdown]
# 1. ***Signal processing*** focuses on analyzing or manipulating a *signal*, often with the purpose of extracting specific information.

# %% [markdown]
# 2. A ***Signal*** may be any measurable function containing information, which varies with time/location etc...

# %% [markdown]
# 3. Signal processing conducted on a computer or other digital processing unit is known as ***Digital Signal Processing***.

# %% [markdown]
# ##### Notes:

# %% [markdown]
# # Where is digital signal processing used?

# %% [markdown]
#
# <div style="width: 100%;">
#     <img src="figures/Fig1_sensorer.png" width="30%" align="right" />
#     Update Figure!
#     <div style="width: 60%">
#     <br>
#     <ul>
#         <li>Practically anywhere we obtain <i>digitized</i> input from the physical world to conduct some task:</li>
#       <ul><li>Computer vision</li>
#         <li>Digital control systems</li>
#         <li>Communication systems</li>
#         <li>Sensory equipment such as radar, sonar, lidar, MRI etc.</li>
#         <li>Much more...</li></ul>
#     </ul>
#     </div>
# </div>

# %% [markdown]
#  # Topics covered in the course AIS2201 - Digital Signal Processing?
#
#
#
# <!--
# * Introduksjon til et omfattende fagområde
#     * Vi skal gjennomgå grunnprinsippene i signalbehandling.
#
#     * Gir et godt grunnlag til videre fordypning i f.eks. diskrét reguleringsteknikk, datasyn eller maskinlæring.
# <br>
#
# * Signalbehandlingsteori i sammenheng med praktisk anvendelse
#     * Teoretiske prinsipp vil utforskes med prosessering av *hele* signal i form av bildefiler, lydfiler m.m.
#
#     * Praktisk bruk involverer ofte behandling av signaler i *sanntid* med hjelp av f.eks. en mikrokontroller. -->

# %% [markdown]
#
# 1. Fundamental theory:
#     * Analysis of predominately digital signals in the time- and frequency domain
#     * Analysis, design and implementation of digital filters

# %% [markdown]
# Signal processing is a large field of study with many areas of specialization.

# %% [markdown]
# 2. Application of theory:
#     * DSP system development/simulation using Python
#     * DSP system implementation on a microprocessor using C/C++

# %% [markdown]
# Almost any situation where digital signal processing principles are used will involve programming. It is therefore essentail to become familiar both with the high-level analysis and design tools which are available, as well as low-level tools used in implementation.

# %% [markdown]
# # Key competences

# %% [markdown]
# * Know how to collect digitized signal information using i microprocessor
#     * Requires programming in C/C++

# %% [markdown]
# * Conduct analysis of digital signals in the time- and frequency domain
#     * Python/Matlab an exceptionally useful tools for signal and systems analysis

# %% [markdown]
# * Design and implement digital filters (or potentially other DSP systems) to serve a specific need
#     * System design benefits from Python/Matlab
#     * System implementation often requires more hardware-specific programming (C/C++)

# %% [markdown]
# <!--* Mange lignende fag (typisk kalt "signals and systems" internasjonalt) fungerer hovedsakelig som en introduksjon til fagfeltet, og forutsetter nesten at man tar flere fag før man begynner å ta teorien skikkelig i bruk.
# * Selv om jeg ønsker å gi dere forutsetningene for å spesialisere videre i området dersom dere tar mastergrad senere, ønsker jeg i hovedsak å utruste dere med kunnskap om å bruke noen grunnleggende verktøy som dukker opp i mange sammenhenger. Selv om man ikke nødvendigvis hanvner i et typisk "signalbehandlings-yrke".-->

# %% [markdown]
# # Balancing theory and practice
# <img src="figures/Fig1_1_Tools.png" width="60%" style="padding:100px" />

# %% [markdown]
# ##### Notes:
# Often, applying signal processing to a specific task will involve a combination of powerful "general purpose" DSP tools such as the FFT or Digital Filters, and then applying some data processing algorithm to the output wich extracts the desired information.
#
# **Example:** Tone detection / frequency detection of a signal will typically use a fourier transform to present the signal in the frequency domain, before idenitfying peak locations, which translates to frequency.

# %% [markdown]
# # Studying signal processing - some recommendations.
#
# * Requires steady work to cultivate a proper understanding of concepts
# * Assignments are an important part of the course
#     * Python as a tool for learning DSP, not "only programming"
# * Focus on the *why*
#     * Tables of formulas will only get you so far
# * Ask questions, we're here to assist (either in the classroom or on e-mail).
#
#
# *The topic may be challenging, but will teach the use of tools which are useful in a variety of applications. Worth the effort!*

# %% [markdown]
# # "Do i have to be good at math?"
#
# * Signal Processing is in general considered a math-heavy topic
# * This course aims to achieve understanding initially hrough practical observation/intuition
# * Reduced emphasis on lengthy mathematical explanations
#     * Graphical analogies such as the one shown may often replace lengthy math proofs
#
# <img src="figures/Fig3_GraphicalMath.png" width="60%" align="right"/>
#
# <!--
# # NEEDS MORE!
#
#
# * Matematiske utregninger for hånd med formeloppslag kan være god trening, men gjør det ikke lett å se sammenhenger.
# * Mange regneoperasjoner kan løses intuitivt med en grafisk tilnærming, og kan også gi en bedre forståelse av sammenhengene.-->

# %% [markdown]
# ##### Notes
# In order to use DSP effectively, you do need to have a solid theoretical understanding of how signals are affected by various signal processing operations. The classical approach to gaining such an understanding is to spend time calculating DSP operations such as fourier transforms by hand, even if such manual calculations are rarely done in practice.
#
# In this course we will not forgo manual calculations entirely, but we will keep them at a minimum while backing up the abstract equations with frequent visualizations and practical examples.

# %% [markdown]
# # DSP and Programming
#
# * ***Essential*** for analyzing signals and systems.
#     * Graphical representation.
#     * Python main programming language.
# * Lectures make use of both *code examples* og *demos*
#     * *Code examples* to show execution of signal processing operations in Python
#     * *Demos* to visualize DSP principles and support theory.
# * Implementing DSP systems requires programming (often hardware-specific).
#     * We will use **C** to program some STM32 microcontrollers

# %% [markdown]
# ## Python script example: *Sinusoid*

# %%
import matplotlib.pyplot as plt
# %matplotlib ipympl

t = np.linspace(0, 1, 501)
x_t = cos(6*np.pi*t)

plt.close(1); plt.figure(1, figsize=(12, 5))
plt.plot(t, x_t, color='tab:orange')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Example demo: audio signal analyzer

# %%
from IPython.display import Audio
from scipy.io import wavfile
fs, data = wavfile.read(r'../data/orca.wav') # les audiofilen 'orca.wav' og lagre til variablene 'fs' og 'data'
xn = data/0x8000
Audio(xn, rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %matplotlib ipympl
from demos import SignalAnalyzer 
SignalAnalyzer(xn, fs);
# Out:
# ...
# Output()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Pre-requisite courses/skills
#
# * Mathematical methods 2 or similar
#     * Differential equations
#     * Complex numbers and functions
#     * Fourier series
#         * Central to Signal Processing
#         * Will be reviewed next week!
# * Statistics
# * Programming experience, preferably in Python and C/C++
# * Control systems is useful, but not a hard requirement
#
#
# <br>
# <br>

# %% [markdown]
# # [Practical information](https://ntnu.blackboard.com/ultra/courses/_56599_1/cl/outline)

# %% [markdown]
# # Weekly Schedule
#
# A typical lecture week is shown below. Changes may occur to certain weeks where a different schedule is appropriate.
#
# * Day 1:
#     - 1-2 hours lecture
#     - 2-3 hours supervized work/lab
# * Day 2:
#     - 1-2 hours lecture
#     - 2-3 hours supervized work/lab

# %% [markdown]
# # Weekly assignments
#
# * A total of 10 weekly jupyter assignments found on [GitHub]
# * Assignments must be reviewed in person during a lab session with a lecturer/student assistant
#     - Deadlines for review are set to end of work day 1
# * At least 7 assignments must have passed review to be allowed to hand in final portfolio.

# %% [markdown]
# <img src="figures/Fig11_STM32.png" width="30%" style="float:right" />
#
# * Encompasses multiple aspects of Signal Processing
#     * Testing theoretical understanding of topics
#     * DSP system design and analysis using Python
#     * Real-time DSP system implementation on an STM32 microcontroller

# %% [markdown]
# # Rough semester overview:
# <br>
# <bt>
#
# <img src="figures/Semester_overview.png" align="left" />

# %% [markdown]
# # Portfolio
#
# * Reports from assignments (7-10)
#     - approx. 20% of grade
#     - Include end-of-year review of assignments.
# * Individual project
#     - approx. 80% of grade
#     - Topics from weekly assignments highly relevant
#     - Encourages creativity
#     - Divided into 3 stages:
#         1. Simulation and test setup
#         2. System development and testing
#         3. System implementation

# %% [markdown]
# # The project!

# %% [markdown]
# * Create a *robust* heart rate monitor.
# ![](figures/noisy_ecg_annotated.png)

# %% [markdown]
# * Detailed information in the [project description](https://ntnu.blackboard.com/bbcswebdav/pid-2869322-dt-content-rid-85423502_1/xid-85423502_1).

# %% [markdown]
# # Key points

# %% [markdown]
# * Assignments must be approved in person each week by end of monday

# %% [markdown]
# * Each session begins with lectures followed by lab work

# %% [markdown]
# * The semester plan has 4 "project weeks"
#     * 2 midway in the semester
#     * 2 at the end of semester

# %% [markdown]
# * Project & reviewed assignments are handed in by end of semester (exam date)

# %% [markdown]
# # Lecturer's appeal:

# %% [markdown]
# * ### Please ask questions!
#     * If you find a topic from the lecture or an assignment to be baffling, there are two possibilities.

# %% [markdown]
# 1. Everyone else in class is quiet because no one else finds the topic challenging.
#     - Despite what i may wish for, this is not the most likely scenario.

# %% [markdown]
# 2. A significant number of your fellow students are also confused, and are hoping someone will ask for further explanation.
#     - Far more likely scenario

# %% [markdown]
# # Any questions?
